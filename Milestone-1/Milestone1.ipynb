# %%
# !pip install matplotlib

# %%
import sys
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

print("🐍 Python version:", sys.version)
print("📷 OpenCV version:", cv2.__version__)
print("🖐️ MediaPipe version:", mp.__version__)
# Out:
# 🐍 Python version: 3.10.19 | packaged by conda-forge | (main, Oct 13 2025, 14:05:01) [MSC v.1944 64 bit (AMD64)]
# 📷 OpenCV version: 4.11.0
# 🖐️ MediaPipe version: 0.10.21

# %%
import cv2
from matplotlib import pyplot as plt
import os
print("Current working directory:",os.getcwd())
# Out:
# Current working directory: C:\Users\Dell

# %%
os.chdir(r"C:\Users\Dell\OneDrive\Desktop\Infosys Springboard Ex 1")
print("Directory changed to:", os.getcwd())
# Out:
# Directory changed to: C:\Users\Dell\OneDrive\Desktop\Infosys Springboard Ex 1

# %%
import cv2
from matplotlib import pyplot as plt

# Load an image
img = cv2.imread('butterfly.jpg', 1)  # Use the correct path

# --- Error Check ---
if img is None:
    print("ERROR: Image could not be loaded!")
    print("Please check that 'butterfly.jpg' exists and the path is correct.")
    # Stop execution here, or handle the error gracefully
else:
    # If the image loaded, proceed with conversion and display
    
    # Convert BGR (OpenCV default) to RGB for Matplotlib display
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Display
    plt.imshow(img_rgb)
    plt.title('Loaded Image with OpenCV')
    plt.axis('off')
    plt.show()

# %%
# Load an image (make sure you have an image file in the same folder)
img = cv2.imread('butterfly.jpg',0)  # replace with your image name
# Convert BGR (OpenCV default) to RGB for Matplotlib display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 
# Display
#plt.imshow(img_rgb)
plt.imshow(img)
plt.title('Displaying a Grayscale Image using OpenCV')
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load original color image
img = cv2.imread('butterfly.jpg', 1)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Rotate 90° clockwise
rotated = cv2.rotate(img_rgb, cv2.ROTATE_90_CLOCKWISE)

# Display
plt.imshow(rotated)
plt.title('Rotated Image 90° Clockwise')
plt.axis('off')
plt.show()

# %%
# 1. Rotate the image 90 degrees Counter-Clockwise (CCW)
# This is often referred to as 'anti-rotation'.
anti_rotated_bgr = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)

# 2. Convert the BGR result to RGB for Matplotlib display
anti_rotated_rgb = cv2.cvtColor(anti_rotated_bgr, cv2.COLOR_BGR2RGB)

# 3. Display the image
plt.imshow(anti_rotated_rgb)
plt.title('Anti-Rotated Image (90° CCW)')
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt


# Load the image (0 = grayscale, remove it for color)
img = cv2.imread('butterfly.jpg', 0)  # Load in grayscale mode

# Print image details
print("Image shape:", img.shape)   # (height, width)
print("Image size:", img.size)     # Total number of pixels
print("Image dtype:", img.dtype)   # Data type of pixel values

# Display the image
plt.imshow(img, cmap='gray')       # Use grayscale colormap for 1-channel image
plt.title('Loaded Image using OpenCV')
plt.axis('off')
plt.show()
# Out:
# Image shape: (736, 736)
# Image size: 541696
# Image dtype: uint8

# %%
import cv2
from matplotlib import pyplot as plt

# Load a color image
img = cv2.imread('butterfly.jpg', 1)  # 1 = color

# Check if image is loaded
if img is None:
    print("ERROR: Image not found! Check the file path.")
else:
    # Convert BGR (OpenCV default) to RGB for Matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Display the image
    plt.imshow(img_rgb)  # Use img_rgb to show correct colors
    plt.title('Loaded Color Image using OpenCV')
    plt.axis('off')      # Hide axes
    plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('butterfly.jpg')

# Convert BGR (OpenCV default) to RGB (for Matplotlib)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Apply Gaussian Blur
blur = cv2.GaussianBlur(img_rgb, (7, 7), 0)

# Display original and blurred images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(blur)
plt.title('Gaussian Blurred Image (7x7)')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the original color image
img = cv2.imread('butterfly.jpg', 1)  # 1 = color (BGR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for correct display

# Convert to grayscale for Canny (edge detection works on single channel)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Canny edge detection
edges = cv2.Canny(gray, 100, 200)

# Display original color image and edges
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Original Color Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title('Canny Edge Detection (from Original Image)')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load image in grayscale
img = cv2.imread('butterfly.jpg', 1)

# Apply simple binary thresholding
img_rgb =cv2.cvtColor( img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img_rgb, 127, 255, cv2.THRESH_BINARY)

plt.imshow(thresh)
plt.title('Binary Threshold (127)')
plt.axis('on')

plt.show()

# %%
import cv2

import mediapipe as mp

import numpy as np

import matplotlib.pyplot as plt

# Quick webcam test (press 'q' to quit)

cap = cv2.VideoCapture(0)

if not cap.isOpened():

    print("Cannot open camera")

else:

    ret, frame = cap.read()

    if ret:

        plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        plt.title('Webcam frame (captured)')

        plt.axis('off')

    cap.release()

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Draw a rectangle (width ≠ height)
    cv2.rectangle(frame, (100, 100), (300, 200), (0, 255, 0), 2)  # 200 width × 100 height

    # Add text annotation
    cv2.putText(frame, "Live annotation", (110, 90),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    # Display the frame
    cv2.imshow("Live Video Annotation", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Draw a filled green circle at (200, 200) with radius 50
    cv2.circle(frame, (200, 200), 50, (0, 255, 0), -1)

    # Add text annotation above the circle
    cv2.putText(frame, "Green Filled Circle", (120, 150),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    # Display the frame
    cv2.imshow("Live Video - Circle Annotation", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Add text annotation
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, "Built using CV2", (100, 100), font, 1, (0, 255, 255), 2)

    # Display the frame
    cv2.imshow("Live Video - Text Annotation", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release camera and close window
cap.release()
cv2.destroyAllWindows()

# %%
# ==========================================
# Capture Video Frames and Save as Images
# ==========================================

import cv2
import time
import os

# Step 1: Create a folder to save captured images
save_folder = "saved_frames"
os.makedirs(save_folder, exist_ok=True)

# Step 2: Open the webcam (0 = default camera)
cap = cv2.VideoCapture(0)

# Step 3: Check if the webcam opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam")
    exit()

# Step 4: Variables for FPS calculation and frame count
prev_time = 0
frame_count = 0

# Step 5: How often to save frames (e.g., every 10th frame)
save_interval = 10  # Change this to 1 to save every frame

print("Press 'q' to quit capturing video...")

while True:
    # Step 6: Read a frame from the camera
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture frame")
        break

    # Step 7: Calculate FPS
    current_time = time.time()
    fps = 1 / (current_time - prev_time) if prev_time else 0
    prev_time = current_time

    # Step 8: Display FPS on the frame
    cv2.putText(frame, f'FPS: {int(fps)}', (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Step 9: Display the frame in a window
    cv2.imshow("Video Frame", frame)

    # Step 10: Save every Nth frame as an image file
    frame_count += 1
    if frame_count % save_interval == 0:
        timestamp = time.strftime("%Y%m%d_%H%M%S")
        filename = os.path.join(save_folder, f"frame_{timestamp}_{frame_count}.jpg")
        cv2.imwrite(filename, frame)
        print(f"Saved: {filename}")

    # Step 11: Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Step 12: Release camera and close windows
cap.release()
cv2.destroyAllWindows()

print("\nVideo capture ended.")
print(f"Images saved in folder: '{os.path.abspath(save_folder)}'")

# %%
import cv2

# Open webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Get frame dimensions
    height, width, _ = frame.shape

    # Draw a rectangle (x1, y1, x2, y2)
    cv2.rectangle(frame, (50, 50), (250, 200), (0, 255, 0), 2)

    # Draw a square (x1, y1, x2, y2)
    cv2.rectangle(frame, (300, 50), (450, 200), (255, 0, 0), 2)

    # Draw a circle (center, radius)
    cv2.circle(frame, (width // 2, height // 2 + 100), 70, (0, 0, 255), 2)

    # Add labels for clarity
    cv2.putText(frame, "Rectangle", (60, 45),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
    cv2.putText(frame, "Square", (310, 45),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)
    cv2.putText(frame, "Circle", (width // 2 - 50, height // 2 + 180),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    # Show live annotated feed
    cv2.imshow("Live Shapes on Camera", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release and close
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

hands = mp_hands.Hands(max_num_hands=2, min_detection_confidence=0.7)

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Flip frame horizontally for mirror effect
    frame = cv2.flip(frame, 1)

    # Convert BGR to RGB
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame
    results = hands.process(frame_rgb)

    # Draw landmarks if detected
    if results.multi_hand_landmarks:
        for hand_landmarks, handedness in zip(results.multi_hand_landmarks,
                                              results.multi_handedness):

            # Draw hand landmarks
            mp_drawing.draw_landmarks(
                frame,
                hand_landmarks,
                mp_hands.HAND_CONNECTIONS,
                mp_drawing_styles.get_default_hand_landmarks_style(),
                mp_drawing_styles.get_default_hand_connections_style()
            )

            # Extract label (Left/Right) and score
            label = handedness.classification[0].label
            score = handedness.classification[0].score

            # Get wrist coordinates
            h, w, _ = frame.shape
            wrist = hand_landmarks.landmark[0]
            cx, cy = int(wrist.x * w), int(wrist.y * h)

            # Display label and score near the wrist
            text = f"{label} ({score:.2f})"
            cv2.putText(frame, text, (cx - 20, cy - 20),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2, cv2.LINE_AA)

    # Show the output
    cv2.imshow("Hand Tracking", frame)

    # Exit on 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
hands.close()
